# %% [markdown]
# # FP: Programming Fundamentals (with Python)
#
# ## CONTENTS
#
# ## L.EIC/2023-24
#
# #### João Correia Lopes$^{1}$, Pedro Vasconcelos$^{2}$, Nuno Macedo$^{1}$
# $^{1}$FEUP/DEI & INESC TEC\
# $^{2}$FCUP/DCC & LIACC

# %% [markdown]
# > The Unit aim at giving the student the ability to create algorithms, and to use a programming language to implement, test, and debug algorithms to solve simple problems.

# %% [markdown]
# ## Introduction
#
# Here you find a collection of Jupyter Notebooks that help you learn basic principles of programming and data structures, and ultimately to embrace the **Computational Thinking**.
#
# The contents are based on:
#   - the open-source book: http://openbookproject.net/thinkcs/python/english3e/index.html
#   - one interactive version of the book: https://runestone.academy/runestone/books/published/thinkcspy/index.html
#
# For more information, go to FP's landing page at: https://moodle.up.pt

# %% [markdown]
# ## Table of Contents
#
# - [00: Preface]
# - [01: Introduction]
# - [02: Variables, expressions and statements]
# - [03: Program flow and conditionals]
# - [04: Iteration]
# - [05: Functions]
# - [06: Fruitful functions]
# - [07: Strings]
# - [08: Tuples]
# - [09: Lists]
# - [10: Work with lists]
# - [11: Dictionaries]
# - [12: Sets]
# - [13: Recursion]
# - [14: Recursion vs. Iteration]
# - [15: Functional Programming with collections]
# - [16: Comprehensions]
# - [17: Higher-order functions]
# - [18: Effect-free programming style]
# - [19: List algorithms]
# - [20: Analysis of algorithms]
# - [21: Modules]
# - [22: Programs]
# - [23: Files]
# - [24: Exceptions]
# - [25: Python packages]
# - [26: Debugging and testing]

# %% [markdown]
# ## Finale
#
# - Whenever deemed necessary, students are encouraged to go to the "Clinic" to get help from the student assistants; see the Attendance hours in [Moodle](https://moodle.up.pt/), and
# - [always look on the bright side of life](https://www.youtube.com/watch?v=JrdEMERq8MA)
#
# Do you know how to run the following Python code?

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('-ECUtkv2qV8')

# %% [markdown]
# -- João Correia Lopes & Pedro Vasconcelos, qui 15 set 2022 14:51:25 WEST
