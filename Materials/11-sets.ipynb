# %% [markdown]
# # NB11: Sets & Frozensets
#
# ## Programming Fundamentals
#
# ## L.EIC/2023-24
#
# #### João Correia Lopes$^{1}$, Pedro Vasconcelos$^{2}$, Nuno Macedo$^{1}$
# $^{1}$FEUP/DEI & INESC TEC\
# $^{2}$FCUP/DCC & LIACC

# %% [markdown]
# ## Goals
#
# By the end of this class, the student should be able to:
#
# - Distinguish between mutable and immutable datatypes & describe aliasing
# - Distinguish between ordered and unordered datatypes
# - Use the main operations and methods available to work with sets
# - Use immutable sets (frozensets)

# %% [markdown]
# ## Bibliography
#
# - Peter Wentworth, Jeffrey Elkner, Allen B. Downey, and Chris Meyers, *How to Think Like a Computer Scientist — Learning with Python 3* (Section 9.1, 9.2) [[PDF](https://media.readthedocs.org/pdf/howtothink/latest/howtothink.pdf)]
# [[HTML](http://openbookproject.net/thinkcs/python/english3e/)]
#
# - Set and Frozensets: <https://www.python-course.eu/python3_sets_frozensets.php>

# %% [markdown]
# > "Program testing can be used to show the presence of bugs, but never to show their absence!"
#
# Edgar Dijkstra

# %% [markdown]
# # 11 Data types: Sets & Frozensets

# %% [markdown]
# ## 11.1 Mutable versus immutable and aliasing

# %% [markdown]
# ### Mutable data types
#
# - Some datatypes in Python are mutable.
# - This means their contents can be changed after they have been created.
# - Lists and dictionaries are good examples of mutable datatypes.
#
# ```python
# >>> my_list = [2, 4, 5, 3, 6, 1]
# >>> my_list[0] = 9
# >>> my_list
# [9, 4, 5, 3, 6, 1]
# ```

# %% [markdown]
# ### Immutable data types
#
# - Tuples and strings are examples of immutable datatypes.
# - Their contents can not be changed after they have been created:
#
# ```python
# >>> my_tuple = (2, 5, 3, 1)
# >>> my_tuple[0] = 9
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# TypeError: 'tuple' object does not support item assignment
# ```

# %% [markdown]
# ### Aliasing
#
# - Mutability is usually useful, but it may lead to something called **aliasing**.
# - In this case, two variables refer to the same object and mutating one will also change the other:
#
# ```python
# >>> list_one = [1, 2, 3, 4, 6]
# >>> list_two = list_one
# >>> list_two is list_one  # same as id(list_two) == id(list_one)
# True
# ```

# %% [markdown]
# ### Cloning
#
# You can escape this problem by making a copy of the list:<sup>1</sup>
# ```python
# >>> list_one = [1, 2, 3, 4, 6]
# >>> list_two = list_one.copy()  # or list_one[:]
# >>> list_one is list_two
# False
#
# >>> list_two[-1] = 5
# >>> list_two
# [1, 2, 3, 4, 5]
# >>> list_one
# [1, 2, 3, 4, 6]
# ```
#
# <sup>1</sup> This is a shallow copy and will not work for nested lists; the module `copy` provides functions to solve this.

# %% [markdown]
# ## 11.2 Sets and Frozensets

# %% [markdown]
# ### Ordered & unordered datatypes (dict)
#
# - Given that tuples and lists are ordered, and dictionaries are unordered (before Python 3.7), we can construct the following table:
#
# |           | Ordered  | Unordered |
# | ---------:|:--------:|:---------:|
# | Mutable   | list     | dict?     |
# | Immutable | tuple    | ?         |
#
# - This reveals an empty spot: we don't know any immutable, unordered datatypes yet.
#
# - Additionally, you can argue that a dictionary doesn't belong in this table, since it is a *mapping type*: a dictionary maps keys to values.

# %% [markdown]
# ### Ordered & unordered datatypes (set)
#
# - A **set** is an unordered, mutable datatype.<sup>2</sup>
#
# - A **frozenset** is an unordered, immutable datatype.
#
# |           | Ordered  | Unordered |
# | ---------:|:--------:|:---------:|
# | Mutable   | list     | set       |
# | Immutable | tuple    | frozenset |
#
# - Since sets and frozensets are unordered, they share some properties with dictionaries:
#   - for example, it’s elements are **unique**.
#
# <sup>2</sup> **The set itself is mutable** (one can add or remove elements to the set), but the **set elements are immutable**

# %% [markdown]
# ### Sets
#
# - A set contains an unordered collection of **unique** and **immutable** objects.
#
# - Sets, unlike lists or tuples, can't have multiple occurrences of the same element.
#
# - Any immutable data type can be an element of a set:
#   - a number, a string, a tuple.
#
# - Mutable (changeable) data types cannot be elements of the set:
#   - A list cannot be an element of a set (but a tuple can).
#   - Another set cannot be an element of a set.
#
# - The requirement of immutability follows from the way sets are implemented.

# %% [markdown]
# ### Create a set using the `set()` function
#
# - We can call the built-in `set()` function with a sequence or another iterable object
# ```python
# >>> A = set('qwerty')
# >>> print(A)
# {'e', 'r', 'q', 't', 'y', 'w'}
# ```

# %% [markdown]
# ### Create a set using the compact notation
#
# - We can also use the compact notation for sets.
# ```python
# >>> A = {1, 2, 3}
# >>> B = {3, 2, 3, 1}
# >>> print(A == B)
# True
# >>> print(B)
# {1, 2, 3}
# ```
#
# $\Rightarrow$
# <https://github.com/fp-leic/public/tree/main/lectures/11/sets.py>

# %% [markdown]
# Try some examples:

# %%
x = set("A Python Tutorial")
print(x)
print(type(x))

# %%
x = set(["Perl", "Python", "Java"])
print(x)

# %%
cities = {"Paris", "Madrid", "London", "Berlin", "Paris", "London"}
print(cities)

# %% [markdown]
# Sets can contain any immutable objects:

# %%
cities = set((("Paris","France"), ("Berlin","Germany"), ("London","UK")))
print(cities)

# %% [markdown]
# Sets may have mixed content (heterogenous):

# %%
# set of mixed datatypes
my_set = {3.14, "Guiness", (1, 2, 3, 4, 5)}
print(my_set)

# %% [markdown]
# ### Frozensets
#
# - Frozensets are like sets except that they cannot be changed, i.e. they are **immutable**.
#
# ```python
# >>> cities = frozenset(["Frankfurt", "Basel", "Freiburg"])
# >>> cities.add("Strasbourg")
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# AttributeError: 'frozenset' object has no attribute 'add'
# ```
#
# - Frozensets are *hashable* and we can use them as dictionary keys and elements of (mutable) sets.
#
# $\Rightarrow$
# <https://github.com/fp-leic/public/tree/main/lectures/11/frozensets.py>

# %% [markdown]
# Try the same with sets:

# %%
cities = set(["Frankfurt", "Basel","Freiburg"])
cities.add("Strasbourg")
print(cities)

# %% [markdown]
# Let's create two frozensets, X and Y:

# %%
X = frozenset([1, 2, 3, 4, 5, 6])
Y = frozenset([4, 5, 6, 7, 8, 9])

print(X)
print(Y)

# %% [markdown]
# ## 11.3 Accessing set elements

# %% [markdown]
# ### Using `for` and `in`
#
# - Python does not provide us with a way of accessing an individual set item.
# - We can use a `for` loop to iterate through all the items of a set.
#
# ```python
# >>> months = set(["Sep", "Oct", "Nov", "Dec", "Jan"])
# >>> for m in months:
# ...     print(m)
# ...
# Jan
# Nov
# Dec
# Oct
# Sep
# ```

# %% [markdown]
# Use `in` to check for the presence of an element:

# %%
months = set(["Sep", "Oct", "Nov", "Dec", "Jan"])
print("Jan" in months)
print("Fev" in months)

# %% [markdown]
# ## 11.4 Adding items to a set

# %% [markdown]
# ### Set method `add()`
#
# - Python allows us to add new items to a set via the `add()` method.
#
# ```python
# >>> N = {1, 2, 3}
# >>> N.add(4)
# >>> print(N)
# {1, 2, 3, 4}
# >>>
# >>> N.add(4)
# >>> print(N)
# {1, 2, 3, 4}
# ```

# %%
months = set(["Sep", "Oct", "Nov", "Dec", "Jan"])
months.add("Fev")
print("Fev" in months)

# %% [markdown]
# ## 11.5 Removing items from a set

# %% [markdown]
# ### Set methods `discard()` and `remove()`
#
# - Python allows us to remove an item from a set, but not using an index as **set elements are not indexed**.
# - The items can be removed using either the `discard()` or `remove()` methods.
#
# ```python
# >>> N = {1, 2, 3, 4, 5, 6}
# >>> N.discard(3)
# >>> print(N)
# {1, 2, 4, 5, 6}
# ```
# ```
# >>> N.remove(2)
# >>> print(N)
# {1, 4, 5, 6}
# ```

# %% [markdown]
# So, what is the difference between `discard()` and `remove()`?

# %%
months = set(["Sep", "Oct", "Nov", "Dec", "Jan"])
months.discard("Fev")
print(months)

# %%
months.remove("Fev")
print(months)

# %% [markdown]
# ### Set method `pop()`
#
# - With the `pop()` method, we can remove and return an element.
# - Since the elements are unordered, we cannot tell or predict the item that will be removed.
#
# ```python
# >>> N = {1, 2, 3, 4, 5, 6}
# >>> print(N.pop())
# 1
# >>> print(N)
# {2, 3, 4, 5, 6}
# ```

# %% [markdown]
# For example:

# %%
months = set(["Sep", "Oct", "Nov", "Dec", "Jan"])
print(months.pop())
print(months.pop())
print(months.pop())

# %% [markdown]
# ### Set method `clear()`
#
# - The Python's `clear()` method helps us remove all elements from a set
#
# ```python
# >>> N = {1, 2, 3, 4, 5, 6}
# >>> N.clear()
# >>> print(N)
# set()
# ```

# %% [markdown]
# ## 11.6 Set alias and cloning

# %% [markdown]
# ### Aliasing
#
# - The assignment just creates a alias, i.e. another name, to the same data structure.
#
# ```python
# >>> N1 = {1, 2, 3, 4, 5, 6}
# >>> N2 = N1
# >>> id(N1) == id(N2)
# True
#
# >>> N1.clear()
# >>> print(N2)
# set()
# ```

# %% [markdown]
# ### Copy
#
# - The method `copy()` creates a *shallow copy*, which is returned.
#
# ```python
# >>> N1 = {1, 2, 3, 4, 5, 6}
# >>> N2 = N1.copy()
# >>> id(N1) == id(N2)
# False
#
# >>> N1.clear()
# >>> print(N2)
# {1, 2, 3, 4, 5, 6}
# ```

# %% [markdown]
# ## 11.7 Set operations
#
# - The set operations are well known from mathematics:
#   - Union, intersection, difference.
#
# - These operations return new sets, they are not mutators.

# %% [markdown]
# ### The joy of sets
#
# - Suppose you have three lists with integers and want the list of the elements present on all three.
#
# ```python
# # Elements in List1
# list1 = [1, 5, 10, 20, 40, 80, 100]
#
# # Elements in List2
# list2 = [6, 7, 20, 80, 100]
#
# # Elements in List3
# list3 = [3, 4, 15, 20, 30, 70, 80, 120]
# ```
#
# $\Rightarrow$
# <https://github.com/fp-leic/public/tree/main/lectures/11/intersect.py>

# %% [markdown]
# That's easy with sets:

# %%
list1 = [1, 5, 10, 20, 40, 80, 100]
list2 = [6, 7, 20, 80, 100]
list3 = [3, 4, 15, 20, 30, 70, 80, 120]

set1 = set(list1)
set2 = set(list2)
set3 = set(list3)

set12 = set1.intersection(set2)
set13 = set12.intersection(set3)
print(set13)

#print(set1.intersection(set2).intersection(set3))

# %% [markdown]
# Set union:

# %%
X = {"a","b","c","d","e"}
Y = {"c","d","e","f","g"}
print(X.union(Y))
print(X | Y)

# %% [markdown]
# Set intersection:

# %%
X = {"a","b","c","d","e"}
Y = {"c","d","e","f","g"}
print(X.intersection(Y))
print(X & Y)

# %% [markdown]
# Set difference:

# %%
X = {"a","b","c","d","e"}
Y = {"c","d","e","f","g"}
print(X.difference(Y))
print(X - Y)

# %% [markdown]
# ### The joy of sets (2)
#
# - Suppose you have two lists with integers and want to find the missing and additional elements when comparing the lists
#
# ```python
# list1 = [1, 2, 3, 4, 5, 6]
# list2 = [4, 5, 6, 7, 8]
# ```
#
# ![difference](https://raw.githubusercontent.com/fp-leic/public/main/notebooks/11/difference.png)
#
# Source: geeksforgeeks
#
# $\Rightarrow$
# <https://github.com/fp-leic/public/tree/main/lectures/11/difference.py>

# %% [markdown]
# ### Set Boolean methods

# %% [markdown]
# The `isdisjoint()` method returns `True` if two sets have a null intersection.

# %%
X = {"a","b","c","d","e"}
Y = {1,2,3}
print(X.isdisjoint(Y))

# %% [markdown]
# The `x.issubset(y)` method returns `True` if `x` is a subset of `y`. `<=` is an abbreviation and `<` is used to check if a set is a proper subset of a set.

# %%
X = {"a","b","c","d","e"}
Y = {"a","b","c"}
print(X.issubset(Y))
print(Y.issubset(X))
print(Y <= X)

# %% [markdown]
# The `x.issuperset(y)` method returns `True` if `x` is a superset of `y`. `>=` is an abbreviation and `>` is used to check if a set is a proper superset of a set.

# %%
X = {"a","b","c","d","e"}
Y = {"c","d"}
print(X.issuperset(Y))
print(X > Y)
print(X >= Y)
print(X > X)
print(X >= X)

# %% [markdown]
# ### The joy of sets (3)
#
# - A **pangram** is a sentence containing every letter in the English Alphabet.
#
# - Lowercase and uppercase letters are considered the same.
#
# - Given a string, check if the given string is pangram or not.
#   - source: https://www.geeksforgeeks.org/python-set-check-string-panagram/
#
# - A normal way would have been to use a frequency table and check if all elements were present or not.

# %% [markdown]
# - But using `import ascii_lowercase` we import all the lowercase characters in a set and all characters of string in another set.
#
# > In the function, two sets are formed:
# - One for all lowercase letters and one for the letters in the string
# - The two sets are subtracted and if it is an empty set, the string is a pangram
#
# $\Rightarrow$
# <https://github.com/fp-leic/public/tree/main/lectures/11/is_pangram.py>

# %% [markdown]
# You can try it here:

# %%
from string import ascii_lowercase as asc_lower

def is_pangram(s):
    """ Function to check if all elements are present or not """
    return set(asc_lower) - set(s.lower()) == set()

if is_pangram("The quick brown cat jumps over the lazy dog"):
    print("That's a pangram!")
else:
    print("That's not a pangram!")

# %% [markdown]
# # Further reading

# %% [markdown]
# ### Set in Python
#
# Python Tutorial || Learn Python Programming -- Socratica

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('sBvaPopWOmQ')

# %% [markdown]
# ### More datatypes

# %% [markdown]
# - More exotic data types (queues, stacks and ordered dictionaries) are provided in Python’s `collections` module.
# - You can find the documentation in the [Python Standard Library](https://docs.python.org/3.7/library/collections.html)

# %% [markdown]
# ### Mutable vs Immutable Objects in Python (summary)
#
# > Everything in Python is an object and
# > objects in Python can be either mutable or immutable
#
# - Since everything in Python is an Object, every variable holds an object instance
# - When an object is initiated, it is assigned a unique object id
# - Its type is defined at runtime and once set can never change, however its state can be changed if it is mutable
# - Simple put, a mutable object can be changed after it is created, and an immutable object can’t
#
# > Objects of built-in types like (`int`, `float`, `bool`, `str`, `tuple`, `frozenset`) are **immutable**.
#
# > Objects of built-in types like (`list`, `dict`, `set`) are **mutable**
#
# $\Rightarrow$
# [towardsdatascience](
# https://towardsdatascience.com/https-towardsdatascience-com-python-basics-mutable-vs-immutable-objects-829a0cb1530a)

# %% [markdown]
# -- João Correia Lopes & Pedro Vasconcelos, 16 out 2022 15:47:16 WEST
